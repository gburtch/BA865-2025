# %% [markdown]
# #**Apply SHAP to Dog-Cat Classifier**

# %% [markdown]
# Mount Google Drive folder.

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Load data using TF Dataset pipelines.

# %%
import tensorflow as tf
from tensorflow.keras.utils import image_dataset_from_directory

base_dir = "drive/My Drive/Teaching/Courses/BA 865/BA865-2025/Lecture Materials/Week 3/dogs-vs-cats"

train_dataset = image_dataset_from_directory(
    base_dir + "/train/",
    image_size=(180, 180),
    batch_size=32)
validation_dataset = image_dataset_from_directory(
    base_dir + "/validation/",
    image_size=(180, 180),
    batch_size=32)
test_dataset = image_dataset_from_directory(
    base_dir + "/test/",
    image_size=(180, 180),
    batch_size=32)
# Out:
# Found 765 files belonging to 2 classes.
# Found 400 files belonging to 2 classes.
# Found 798 files belonging to 2 classes.

# %% [markdown]
# Define model...

# %%
from tensorflow import keras
from keras import layers

inputs = keras.Input(shape=(180, 180, 3))

### Note that SHAP DeepExplainer doesn't know how to handle 'custom' layers.
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(inputs)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.Flatten()(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

model.summary()
# Out:
# Model: "functional_11"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_30 (InputLayer)     │ (None, 180, 180, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_69 (Conv2D)              │ (None, 178, 178, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_67 (MaxPooling2D) │ (None, 89, 89, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_70 (Conv2D)              │ (None, 87, 87, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_68 (MaxPooling2D) │ (None, 43, 43, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_71 (Conv2D)              │ (None, 41, 41, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_69 (MaxPooling2D) │ (None, 20, 20, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_72 (Conv2D)              │ (None, 18, 18, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_70 (MaxPooling2D) │ (None, 9, 9, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_73 (Conv2D)              │ (None, 7, 7, 256)      │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ (None, 12544)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_22 (Dense)                │ (None, 1)              │        12,545 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 991,041 (3.78 MB)
#  Trainable params: 991,041 (3.78 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Fit the model with a callback...

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="drive/My Drive/Teaching/Courses/BA 865/BA865-2025/Lecture Materials/Week 3/convnet_dog_cat.keras",
        save_best_only=True,
        monitor="val_loss")
]

history = model.fit(
    train_dataset,
    epochs=40,
    batch_size=32,
    validation_data=validation_dataset,
    callbacks=callbacks)
# Out:
# Epoch 1/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 146ms/step - accuracy: 0.5072 - loss: 131.9898 - val_accuracy: 0.5025 - val_loss: 0.7583
# Epoch 2/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - accuracy: 0.6058 - loss: 0.6900 - val_accuracy: 0.5400 - val_loss: 0.6864
# Epoch 3/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - accuracy: 0.5943 - loss: 0.6502 - val_accuracy: 0.6450 - val_loss: 0.6462
# Epoch 4/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.6092 - loss: 0.7392 - val_accuracy: 0.5825 - val_loss: 0.6747
# Epoch 5/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - accuracy: 0.5585 - loss: 0.7948 - val_accuracy: 0.5150 - val_loss: 0.6975
# Epoch 6/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - accuracy: 0.5809 - loss: 0.6928 - val_accuracy: 0.6000 - val_loss: 0.6595
# Epoch 7/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - accuracy: 0.6232 - loss: 0.7722 - val_accuracy: 0.6150 - val_loss: 0.7115
# Epoch 8/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.6793 - loss: 0.5980 - val_accuracy: 0.5250 - val_loss: 4.8801
# Epoch 9/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - accuracy: 0.6131 - loss: 1.4544 - val_accuracy: 0.5925 - val_loss: 0.7627
# Epoch 10/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.7601 - loss: 0.5038 - val_accuracy: 0.6375 - val_loss: 0.8765
# Epoch 11/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - accuracy: 0.7743 - loss: 0.4547 - val_accuracy: 0.6125 - val_loss: 0.8828
# Epoch 12/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - accuracy: 0.8454 - loss: 0.3762 - val_accuracy: 0.6200 - val_loss: 1.0391
# Epoch 13/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.8660 - loss: 0.2968 - val_accuracy: 0.5600 - val_loss: 1.5704
# Epoch 14/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.7899 - loss: 0.5228 - val_accuracy: 0.6250 - val_loss: 1.5120
# Epoch 15/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.9178 - loss: 0.2565 - val_accuracy: 0.6350 - val_loss: 1.2764
# Epoch 16/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - accuracy: 0.9522 - loss: 0.1545 - val_accuracy: 0.5725 - val_loss: 2.3399
# Epoch 17/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - accuracy: 0.9169 - loss: 0.3808 - val_accuracy: 0.6175 - val_loss: 1.6098
# Epoch 18/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.9561 - loss: 0.1016 - val_accuracy: 0.6450 - val_loss: 1.9863
# Epoch 19/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.9508 - loss: 0.1959 - val_accuracy: 0.6375 - val_loss: 1.7133
# Epoch 20/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.9786 - loss: 0.0725 - val_accuracy: 0.5725 - val_loss: 1.9534
# Epoch 21/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - accuracy: 0.9427 - loss: 0.1370 - val_accuracy: 0.6400 - val_loss: 2.0957
# Epoch 22/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - accuracy: 0.9791 - loss: 0.0532 - val_accuracy: 0.5900 - val_loss: 2.6086
# Epoch 23/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - accuracy: 0.9502 - loss: 0.1288 - val_accuracy: 0.6100 - val_loss: 2.4926
# Epoch 24/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.9613 - loss: 0.0850 - val_accuracy: 0.5925 - val_loss: 4.2491
# Epoch 25/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.9517 - loss: 0.1835 - val_accuracy: 0.6125 - val_loss: 2.8227
# Epoch 26/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - accuracy: 0.9414 - loss: 0.2235 - val_accuracy: 0.6050 - val_loss: 2.5997
# Epoch 27/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - accuracy: 0.9871 - loss: 0.0450 - val_accuracy: 0.6250 - val_loss: 3.2447
# Epoch 28/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - accuracy: 0.9491 - loss: 0.2854 - val_accuracy: 0.6225 - val_loss: 3.5623
# Epoch 29/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - accuracy: 0.9806 - loss: 0.0486 - val_accuracy: 0.6450 - val_loss: 3.3310
# Epoch 30/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.9884 - loss: 0.0649 - val_accuracy: 0.6150 - val_loss: 3.8573
# Epoch 31/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - accuracy: 0.9777 - loss: 0.1008 - val_accuracy: 0.6400 - val_loss: 3.4165
# Epoch 32/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.9705 - loss: 0.1364 - val_accuracy: 0.6300 - val_loss: 3.6880
# Epoch 33/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 1.0000 - loss: 5.8354e-04 - val_accuracy: 0.6375 - val_loss: 3.9645
# Epoch 34/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - accuracy: 1.0000 - loss: 1.5176e-04 - val_accuracy: 0.6450 - val_loss: 4.0762
# Epoch 35/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 1.0000 - loss: 2.3261e-05 - val_accuracy: 0.6300 - val_loss: 4.1867
# Epoch 36/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - accuracy: 1.0000 - loss: 1.0722e-05 - val_accuracy: 0.6325 - val_loss: 4.3111
# Epoch 37/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - accuracy: 1.0000 - loss: 6.5168e-06 - val_accuracy: 0.6375 - val_loss: 4.4489
# Epoch 38/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 1.0000 - loss: 3.5366e-06 - val_accuracy: 0.6400 - val_loss: 4.6074
# Epoch 39/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 1.0000 - loss: 2.2099e-06 - val_accuracy: 0.6375 - val_loss: 4.7235
# Epoch 40/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - accuracy: 1.0000 - loss: 1.2841e-06 - val_accuracy: 0.6400 - val_loss: 4.7973

# %% [markdown]
# As before, this model gets to about 70% accuracy in the test data.

# %%
from tensorflow import keras

test_model = keras.models.load_model("drive/My Drive/Teaching/Courses/BA 865/BA865-2025/Lecture Materials/Week 3/convnet_dog_cat.keras")
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc}")
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 22s 849ms/step - accuracy: 0.5907 - loss: 0.6683
# Test accuracy: 0.6203007698059082

# %% [markdown]
# #**SHAP Deep Explainer**

# %%
# !pip install shap
import shap
import numpy as np
import glob
from PIL import Image

# Let's get 100 cats.
images = []
ind = 0
for file in glob.glob(f"{base_dir}/train/cats/*"):
    im=Image.open(file)
    im=im.resize(size=(180,180))
    images.append(np.divide(np.array(im),255))
    ind += 1
    if ind == 100:
      break

# Let's also get 100 dogs.
ind = 0
for file in glob.glob(f"{base_dir}/train/dogs/*"):
    im=Image.open(file)
    im=im.resize(size=(180,180))
    images.append(np.divide(np.array(im),255))
    ind += 1
    if ind == 100:
      break

background = np.stack(images)
# Out:
# Requirement already satisfied: shap in /usr/local/lib/python3.11/dist-packages (0.47.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from shap) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from shap) (1.14.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from shap) (1.6.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from shap) (2.2.2)
# Requirement already satisfied: tqdm>=4.27.0 in /usr/local/lib/python3.11/dist-packages (from shap) (4.67.1)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.11/dist-packages (from shap) (24.2)
# Requirement already satisfied: slicer==0.0.8 in /usr/local/lib/python3.11/dist-packages (from shap) (0.0.8)
# Requirement already satisfied: numba>=0.54 in /usr/local/lib/python3.11/dist-packages (from shap) (0.60.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from shap) (3.1.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from shap) (4.13.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.54->shap) (0.43.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->shap) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->shap) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->shap) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->shap) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->shap) (1.17.0)

# %%
import matplotlib.pyplot as plt

# explain predictions of the model on three images
e = shap.DeepExplainer(test_model, background)

cat_path = keras.utils.get_file(
    fname="cat6.jpg",
    origin="https://www.brightstarbuddies.com.au/blog/wp-content/uploads/sites/8/Bellamy.jpg")

dog_path = keras.utils.get_file(
    fname="dog.jpeg",
    origin="https://hips.hearstapps.com/hmg-prod/images/little-cute-maltipoo-puppy-royalty-free-image-1652926025.jpg"
)

def get_img_array(img_path, target_size):
    img = keras.utils.load_img(
        img_path, target_size=target_size)
    array = keras.utils.img_to_array(img)
    array = np.expand_dims(array, axis=0)
    return array

cat_tensor = get_img_array(cat_path, target_size=(180, 180))
dog_tensor = get_img_array(dog_path, target_size=(180, 180))

plt.axis("off")
plt.imshow(cat_tensor[0].astype("uint8"))
plt.show()
plt.axis("off")
plt.imshow(dog_tensor[0].astype("uint8"))
plt.show()

test_set = np.stack((cat_tensor,dog_tensor),axis=0)
test_set = test_set[:, 0, :, :, :]
print(test_set.shape)

# For some reason we have an extra dimension to our shap_values output.
# Dropping the extra dimension from the shap_values tensor using np.squeeze()
shap_values = e.shap_values(test_set)
# Out:
# (2, 180, 180, 3)
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: input_layer_30
# Received: inputs=['Tensor(shape=(400, 180, 180, 3))']
#   warnings.warn(msg)

# %% [markdown]
# Note that I'm indexing the shap_values tensor to drop an extra (unecessary) dimension that the function is returning.

# %%
shap.image_plot(shap_values[:,:,:,:,0],pixel_values=test_set.astype('uint8'))
