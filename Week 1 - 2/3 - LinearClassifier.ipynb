# %% [markdown]
# #**Linear Classifier from Scratch in Tensorflow**

# %% [markdown]
# We are now going to go through the book's example of implementing a linear classifier from scratch using Tensorflow. We already demonstrated our procedure using Keras + Tensorflow, so this is just another example to reinforce understanding.

# %% [markdown]
# #*Simulate Data*

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd # for cross tabulation to make confusion matrix.

# We will ultimately have 2000 observations, 1000 1's and 1000 0's. 
# We are drawing a two inputs (x's) which are jointly normal, taking on average values of 0 and 3 when the outcome is 0, and values of 3 and 0 when the outcome is 1. 
# The cov are covariance matrices, defining how the two x's associate with one another. 
num_samples_per_class = 1000 
negative_samples = np.random.multivariate_normal(
    mean=[0, 3],
    cov=[[1, 0.5],[0.5, 1]],
    size=num_samples_per_class)
positive_samples = np.random.multivariate_normal(
    mean=[3, 0],
    cov=[[1, 0.5],[0.5, 1]],
    size=num_samples_per_class)

# Now we stack the two vector pairs together into a single dataset. 
samples = np.vstack((negative_samples,positive_samples))

labels = np.vstack((np.zeros((1000,1)),np.ones((1000,1))))

# %% [markdown]
# Plotting the resultant data...

# %%
# We make a scatter plot of the first and second columns of the samples matrix (x1 and x2)
# The colors are assigned based on the target label for each observation.
plt.scatter(samples[:,0],samples[:,1],c=labels[:,0])
plt.show()

# %% [markdown]
# #*Define Data, Parameters, and Model*

# %%
# Our first layer is the two inputs, and then we have it mapping directly into an output layer, which yields a continuous prediction. 
# We will apply a threshold to the prediction to get our classification.
input_dim = 2
output_dim = 1

# Here we define matrix W and vector b, our weights and biases.
W = tf.Variable(initial_value=tf.random.uniform(shape=(input_dim, output_dim)))
b = tf.Variable(initial_value=tf.zeros(shape=(output_dim,)))

# This is just the w*x+b without an activation.
def model(inputs):
    return tf.matmul(inputs, W) + b
    
# We will use MSE loss: mean[(target-prediction)^2]
def square_loss(predictions,targets):
    per_sample_losses = tf.square(targets - predictions)
    return tf.reduce_mean(per_sample_losses)

# This is the scalar multiple we will apply against gradients for the updates.
learning_rate = 0.1 

# A single training step will take the input data, and the target labels.
# It performs a forward pass, calculates current loss, does the backward pass to get gradients...
# Finally, it updates W and b based on resulting gradients.
def training_step(inputs, targets):
    with tf.GradientTape() as tape:
        predictions = model(inputs)
        loss = square_loss(predictions, targets)
    grad_loss_wrt_W, grad_loss_wrt_b = tape.gradient(loss, [W, b])
    W.assign_sub(grad_loss_wrt_W * learning_rate) # assign_sub() subtracts the argument value from the current value in place. 
    b.assign_sub(grad_loss_wrt_b * learning_rate)
    return loss

# %% [markdown]
# Now we can implement our linear classifier (note, in econometrics, we would call this a linear probability model). We first take our simulated data and declare it as tensors that Tensorflow can work with. Defining these as float32 because they were originally doubles. Need them to match datatype with the weight tensors.

# %%
data = tf.constant(samples,dtype="float32")
groundTruth = tf.constant(labels,dtype="float32")

for step in range(40):

    loss = training_step(data,groundTruth)
    print("Loss at step ",step,": ",loss.numpy(),sep="")
# Out:
# Loss at step 0: 3.4226305
# Loss at step 1: 0.5392888
# Loss at step 2: 0.18897264
# Loss at step 3: 0.1316504
# Loss at step 4: 0.11654073
# Loss at step 5: 0.10800722
# Loss at step 6: 0.100944154
# Loss at step 7: 0.09458188
# Loss at step 8: 0.08876979
# Loss at step 9: 0.083448656
# Loss at step 10: 0.078575306
# Loss at step 11: 0.07411184
# Loss at step 12: 0.07002373
# Loss at step 13: 0.06627943
# Loss at step 14: 0.06285001
# Loss at step 15: 0.059709005
# Loss at step 16: 0.05683214
# Loss at step 17: 0.05419721
# Loss at step 18: 0.051783875
# Loss at step 19: 0.049573485
# Loss at step 20: 0.047548994
# Loss at step 21: 0.045694754
# Loss at step 22: 0.043996446
# Loss at step 23: 0.042440962
# Loss at step 24: 0.041016296
# Loss at step 25: 0.039711434
# Loss at step 26: 0.03851631
# Loss at step 27: 0.03742169
# Loss at step 28: 0.03641912
# Loss at step 29: 0.035500865
# Loss at step 30: 0.03465984
# Loss at step 31: 0.033889543
# Loss at step 32: 0.033184014
# Loss at step 33: 0.032537825
# Loss at step 34: 0.031945985
# Loss at step 35: 0.031403907
# Loss at step 36: 0.030907419
# Loss at step 37: 0.030452684
# Loss at step 38: 0.030036192
# Loss at step 39: 0.029654726

# %% [markdown]
# Now, we can pull out the predictions from the final fit model, and apply a threshold of 0.5 for the predictions (1 vs 0).

# %%
# It does a pretty good job. 
predictions = model(data)
plt.scatter(data[:, 0], data[:, 1], c=predictions[:, 0] > 0.5)
plt.show()

confusionMatrix = pd.DataFrame({"Predicted":predictions[:,0]>0.5,"Actual":groundTruth[:,0].numpy().astype(bool)})
pd.crosstab(confusionMatrix['Predicted'],confusionMatrix['Actual'])
# Out:
# Actual     False  True
# Predicted
# False       1000     4
# True           0   996

# %% [markdown]
# #**Again, using Keras, with Validation**

# %% [markdown]
# We are going to train the same classifier again. This time, however, we are going to use the Keras API to simplify things, and we will incorporate a holdout dataset for model evaluation.

# %%
from tensorflow import keras 
from tensorflow.keras import layers
  
model = keras.Sequential([
    layers.Dense(1, activation="linear")
])

model.compile(optimizer="rmsprop",
              loss="mse",
              metrics=["mae","accuracy"])

# Here we are taking the row indices of the data and scrambling their order.  
indices_permutation = np.random.permutation(len(samples))

# We are then using the result to shuffle the observations in our data.
shuffled_inputs = samples[indices_permutation]
shuffled_targets = labels[indices_permutation]
 
# Here we are saying that 30% of the data will be selected to serve as validation.
num_validation_samples = int(0.3 * len(samples))

# Now we are pulling out the validation samples.
val_inputs = shuffled_inputs[:num_validation_samples]
val_targets = shuffled_targets[:num_validation_samples]

# And here we are pulling out the training samples.
training_inputs = shuffled_inputs[num_validation_samples:]
training_targets = shuffled_targets[num_validation_samples:]

# Finally, when we call the fit function, we separately specify training data and validation data.
# We indicate the latter using the validation_data argument. 
history = model.fit(
    training_inputs,
    training_targets,
    epochs=60,
    batch_size=50,
    validation_data=(val_inputs, val_targets),
    shuffle=True
)
# Out:
# Epoch 1/60
# 28/28 [==============================] - 0s 6ms/step - loss: 20.4576 - mae: 4.0018 - accuracy: 0.4814 - val_loss: 21.0778 - val_mae: 4.0640 - val_accuracy: 0.4750
# Epoch 2/60
# 28/28 [==============================] - 0s 3ms/step - loss: 19.3455 - mae: 3.8862 - accuracy: 0.4807 - val_loss: 19.9909 - val_mae: 3.9511 - val_accuracy: 0.4733
# Epoch 3/60
# 28/28 [==============================] - 0s 3ms/step - loss: 18.3598 - mae: 3.7789 - accuracy: 0.4779 - val_loss: 18.9660 - val_mae: 3.8416 - val_accuracy: 0.4733
# Epoch 4/60
# 28/28 [==============================] - 0s 3ms/step - loss: 17.3885 - mae: 3.6717 - accuracy: 0.4771 - val_loss: 17.9481 - val_mae: 3.7301 - val_accuracy: 0.4683
# Epoch 5/60
# 28/28 [==============================] - 0s 2ms/step - loss: 16.4521 - mae: 3.5644 - accuracy: 0.4750 - val_loss: 16.9731 - val_mae: 3.6201 - val_accuracy: 0.4667
# Epoch 6/60
# 28/28 [==============================] - 0s 3ms/step - loss: 15.5373 - mae: 3.4581 - accuracy: 0.4736 - val_loss: 16.0286 - val_mae: 3.5106 - val_accuracy: 0.4667
# Epoch 7/60
# 28/28 [==============================] - 0s 3ms/step - loss: 14.6593 - mae: 3.3517 - accuracy: 0.4721 - val_loss: 15.1094 - val_mae: 3.4003 - val_accuracy: 0.4667
# Epoch 8/60
# 28/28 [==============================] - 0s 2ms/step - loss: 13.7961 - mae: 3.2453 - accuracy: 0.4714 - val_loss: 14.2077 - val_mae: 3.2888 - val_accuracy: 0.4667
# Epoch 9/60
# Epoch 26/60
# 28/28 [==============================] - 0s 2ms/step - loss: 3.3046 - mae: 1.4855 - accuracy: 0.3986 - val_loss: 3.3199 - val_mae: 1.4729 - val_accuracy: 0.3933
# Epoch 27/60
# 28/28 [==============================] - 0s 3ms/step - loss: 2.9911 - mae: 1.4103 - accuracy: 0.3864 - val_loss: 2.9983 - val_mae: 1.3948 - val_accuracy: 0.3833
# Epoch 28/60
# 28/28 [==============================] - 0s 3ms/step - loss: 2.6951 - mae: 1.3391 - accuracy: 0.3714 - val_loss: 2.6936 - val_mae: 1.3207 - val_accuracy: 0.3717
# Epoch 29/60
# 28/28 [==============================] - 0s 2ms/step - loss: 2.4306 - mae: 1.2735 - accuracy: 0.3550 - val_loss: 2.4245 - val_mae: 1.2554 - val_accuracy: 0.3600
# Epoch 30/60
# 28/28 [==============================] - 0s 3ms/step - loss: 2.1909 - mae: 1.2116 - accuracy: 0.3414 - val_loss: 2.1823 - val_mae: 1.1946 - val_accuracy: 0.3517
# Epoch 31/60
# 28/28 [==============================] - 0s 2ms/step - loss: 1.9702 - mae: 1.1537 - accuracy: 0.3321 - val_loss: 1.9562 - val_mae: 1.1346 - val_accuracy: 0.3417
# Epoch 32/60
# 28/28 [==============================] - 0s 2ms/step - loss: 1.7610 - mae: 1.0945 - accuracy: 0.3307 - val_loss: 1.7458 - val_mae: 1.0748 - val_accuracy: 0.3500
# Epoch 33/60
# 28/28 [==============================] - 0s 2ms/step - loss: 1.5706 - mae: 1.0366 - accuracy: 0.3321 - val_loss: 1.5513 - val_mae: 1.0148 - val_accuracy: 0.3567
# Epoch 34/60
# 28/28 [==============================] - 0s 3ms/step - loss: 1.3901 - mae: 0.9772 - accuracy: 0.3429 - val_loss: 1.3702 - val_mae: 0.9550 - val_accuracy: 0.3633
# Epoch 35/60
# 28/28 [==============================] - 0s 3ms/step - loss: 1.2239 - mae: 0.9187 - accuracy: 0.3471 - val_loss: 1.2034 - val_mae: 0.8955 - val_accuracy: 0.3750
# Epoch 36/60
# 28/28 [==============================] - 0s 2ms/step - loss: 1.0674 - mae: 0.8585 - accuracy: 0.3614 - val_loss: 1.0461 - val_mae: 0.8350 - val_accuracy: 0.3950
# Epoch 37/60
# 28/28 [==============================] - 0s 2ms/step - loss: 0.9232 - mae: 0.7981 - accuracy: 0.3793 - val_loss: 0.9022 - val_mae: 0.7762 - val_accuracy: 0.4133
# Epoch 38/60
# 28/28 [==============================] - 0s 4ms/step - loss: 0.7936 - mae: 0.7401 - accuracy: 0.3957 - val_loss: 0.7732 - val_mae: 0.7180 - val_accuracy: 0.4333
# Epoch 39/60
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6772 - mae: 0.6824 - accuracy: 0.4300 - val_loss: 0.6577 - val_mae: 0.6613 - val_accuracy: 0.4500
# Epoch 40/60
# 28/28 [==============================] - 0s 2ms/step - loss: 0.5745 - mae: 0.6272 - accuracy: 0.4636 - val_loss: 0.5576 - val_mae: 0.6079 - val_accuracy: 0.4950
# Epoch 41/60
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4824 - mae: 0.5729 - accuracy: 0.5093 - val_loss: 0.4657 - val_mae: 0.5535 - val_accuracy: 0.5417
# Epoch 42/60
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4029 - mae: 0.5195 - accuracy: 0.5607 - val_loss: 0.3876 - val_mae: 0.5032 - val_accuracy: 0.5883
# Epoch 43/60
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3355 - mae: 0.4711 - accuracy: 0.6107 - val_loss: 0.3225 - val_mae: 0.4559 - val_accuracy: 0.6300
# Epoch 44/60
# 28/28 [==============================] - 0s 3ms/step - loss: 0.2807 - mae: 0.4280 - accuracy: 0.6600 - val_loss: 0.2701 - val_mae: 0.4144 - val_accuracy: 0.6833
# Epoch 45/60
# 28/28 [==============================] - 0s 3ms/step - loss: 0.2372 - mae: 0.3903 - accuracy: 0.7093 - val_loss: 0.2281 - val_mae: 0.3800 - val_accuracy: 0.7117
# Epoch 46/60
# 28/28 [==============================] - 0s 2ms/step - loss: 0.2022 - mae: 0.3582 - accuracy: 0.7629 - val_loss: 0.1940 - val_mae: 0.3509 - val_accuracy: 0.7683
# Epoch 47/60
# 28/28 [==============================] - 0s 3ms/step - loss: 0.1744 - mae: 0.3315 - accuracy: 0.7979 - val_loss: 0.1666 - val_mae: 0.3250 - val_accuracy: 0.8050
# Epoch 48/60
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1503 - mae: 0.3071 - accuracy: 0.8329 - val_loss: 0.1430 - val_mae: 0.3006 - val_accuracy: 0.8400
# Epoch 49/60
# 28/28 [==============================] - 0s 3ms/step - loss: 0.1313 - mae: 0.2873 - accuracy: 0.8650 - val_loss: 0.1248 - val_mae: 0.2813 - val_accuracy: 0.8700
# Epoch 50/60
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1164 - mae: 0.2712 - accuracy: 0.8921 - val_loss: 0.1104 - val_mae: 0.2647 - val_accuracy: 0.9017
# Epoch 51/60
# 28/28 [==============================] - 0s 3ms/step - loss: 0.1043 - mae: 0.2573 - accuracy: 0.9107 - val_loss: 0.0993 - val_mae: 0.2513 - val_accuracy: 0.9233
# Epoch 52/60
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0955 - mae: 0.2467 - accuracy: 0.9257 - val_loss: 0.0909 - val_mae: 0.2411 - val_accuracy: 0.9317
# Epoch 53/60
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0882 - mae: 0.2374 - accuracy: 0.9343 - val_loss: 0.0840 - val_mae: 0.2321 - val_accuracy: 0.9417
# Epoch 54/60
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0820 - mae: 0.2289 - accuracy: 0.9414 - val_loss: 0.0780 - val_mae: 0.2235 - val_accuracy: 0.9483
# Epoch 55/60
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0758 - mae: 0.2205 - accuracy: 0.9486 - val_loss: 0.0723 - val_mae: 0.2148 - val_accuracy: 0.9600
# Epoch 56/60
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0702 - mae: 0.2121 - accuracy: 0.9571 - val_loss: 0.0670 - val_mae: 0.2069 - val_accuracy: 0.9683
# Epoch 57/60
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0650 - mae: 0.2041 - accuracy: 0.9614 - val_loss: 0.0628 - val_mae: 0.1998 - val_accuracy: 0.9750
# Epoch 58/60
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0602 - mae: 0.1966 - accuracy: 0.9693 - val_loss: 0.0581 - val_mae: 0.1918 - val_accuracy: 0.9800
# Epoch 59/60
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0557 - mae: 0.1892 - accuracy: 0.9750 - val_loss: 0.0539 - val_mae: 0.1846 - val_accuracy: 0.9833
# Epoch 60/60
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0515 - mae: 0.1821 - accuracy: 0.9771 - val_loss: 0.0496 - val_mae: 0.1771 - val_accuracy: 0.9883

# %% [markdown]
# After the model fitting is complete, we call the evaluate function, and pass it the validation data (or, typically, some test / holdout data). Note that batch size here is not the same batch size in the fit() call. Batch size here refers to batches of observations in validation data to run through (predictions and loss calculations)

# %%
loss_and_metrics = model.evaluate(val_inputs, val_targets, batch_size=128)

history_dict = history.history
history_dict.keys()

# Notice that there's basically no overfitting going on.
# Because there's no noise in the data for the network to fit to! 
trn_loss_values = history_dict["loss"]
val_loss_values = history_dict["val_loss"]
epochs = range(1, len(trn_loss_values) + 1)
plt.plot(epochs, trn_loss_values, "bo", label="Training loss")
plt.plot(epochs, val_loss_values, "b", label="Validation loss")
plt.title("Training and Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()
# Out:
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0496 - mae: 0.1771 - accuracy: 0.9883
