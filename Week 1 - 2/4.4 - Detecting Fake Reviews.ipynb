# %% [markdown]
# #**Detecting Fake Reviews**

# %% [markdown]
# This dataset is the product of research by a few folks in Computer Science: https://aclanthology.org/N13-1053.pdf. There even used to be a consumer-facing tool based on the model, here: https://web.archive.org/web/20220705181250/http://reviewskeptic.com/.

# %%
import tensorflow as tf
from tensorflow import keras
from google.colab import files
import pandas as pd
import io

trip_advisor = pd.read_csv('https://raw.githubusercontent.com/gburtch/BA865-2025/refs/heads/main/datasets/deceptive-opinion.csv')

#uploaded = files.upload()
#trip_advisor = pd.read_csv(io.BytesIO(uploaded['deceptive-opinion.csv']))
trip_advisor.describe(include='all')
# Out:
#        deceptive   hotel  polarity source  \
# count       1600    1600      1600   1600
# unique         2      20         2      3
# top     truthful  conrad  positive  MTurk
# freq         800      80       800    800
#
#                                                      text
# count                                                1600
# unique                                               1596
# top     The Omni was chosen for it's location whichwor...
# freq                                                    2

# %% [markdown]
# We can use some of the Keras utilities to pre-process the text.
#
# *Q: What features should we use for our prediction?*

# %%
import numpy as np
from tensorflow.keras.preprocessing.text import text_to_word_sequence

# The dataset is perfectly balanced, so 50% accuracy will be equivalent to a random guess.
labels = np.where(trip_advisor['deceptive']=='truthful',0,1)

text = []
for i in range(len(trip_advisor)):
  text.append(text_to_word_sequence(trip_advisor['text'][i])) # This strips punctuation, odd characters, and makes things lower-case.

# %% [markdown]
# This is another pre-processing step, but it's optional.
#
# *Q: What does this code block do?*

# %%
min_freq = 1

word_freq = {}
for review in text:
  for term in review:
    try:
        word_freq[term] = word_freq[term]+1
    except KeyError:
        word_freq[term] = 1

max_freq = max(i for i in word_freq.values())
for i in range(len(text)):
  text[i] = [term for term in text[i] if word_freq[term] >= min_freq & word_freq[term] <= max_freq]

# %% [markdown]
# Here, we are making our integer codings for the text tokens.

# %%
# We declare a set, which we populate from terms from the corpus, one by one.
# Sets only allow 'unique' values.
unique_terms = {term for review in text for term in review}
print(f'We have {len(unique_terms)} unique tokens in our dataset.')

# We can then easily make a term-integer dictionary and an integer-term dictionary (for reverse lookup)
word_index = {term: number for number, term in enumerate(unique_terms)}
reverse_index = {number: term for number, term in enumerate(unique_terms)}
# Out:
# We have 10275 unique tokens in our dataset.

# %% [markdown]
# One-hot encoding the text can be done very explicitly now, as a nested loop.

# %%
def vectorize_sequences(sequences, dimension=len(unique_terms)):
    # Make our blank matrix of 0's to store hot encodings.
    results = np.zeros((len(sequences), dimension))

    # For each observation and element in that observation,
    # Update the blank matrix to a 1 at row obs, column element value.
    for i, sequence in enumerate(sequences):
        for j in sequence:
            results[i, word_index[j]] = 1.
    return results

text_onehot = vectorize_sequences(text)

text_onehot.shape
# Out:
# (1600, 10275)

# %% [markdown]
# Don't forget we have a few other features in the data. It's not just about the review text...

# %%
# One hot encoding the hotels.
hotel_dict = {hotel : index for index, hotel in enumerate(set(trip_advisor['hotel']))}
hotels = []
for hotel in trip_advisor['hotel']:
  hotels.append(hotel_dict[hotel])

hotels_onehot = keras.utils.to_categorical(np.array(hotels))

# One hot encoding the review source
#source_int = np.where(np.array(trip_advisor['source'])=='MTurk',0,np.where(np.array(trip_advisor['source'])=='TripAdvisor',1,2))
#source_onehot = keras.utils.to_categorical(source_int)

# Binarizing the polarity
polarity_bin = np.where(np.array(trip_advisor['polarity'])=="negative",0,1).reshape(1600,1)

# Last step, we shuffle the data
data_onehot = np.concatenate((labels.reshape(1600,1),text_onehot,hotels_onehot,polarity_bin),axis=1)
np.random.shuffle(data_onehot)

# Then we pull out predictors and labels.
predictors = data_onehot[:,1:]
labels = data_onehot[:,0]

# %% [markdown]
# Now we can fit out model to the resulting data. Once again we have k-fold cross validation here.

# %%
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import random

random.seed(12345)

def build_model():
    model = keras.Sequential([
        layers.BatchNormalization(),
        layers.Dropout(0.4),
        # This is essentially a dense layer that mimics a word embedding to some extent, though much less flexible than a real embedding layer
        # We are reducing the one-hot encoded text (10,000+ one-hot tokens) down to 750 latent dimensions.
        layers.Dense(750, activation="linear",kernel_regularizer="l2"),
        layers.Dense(50, activation="relu",kernel_regularizer="l2"),
        layers.Dense(1, activation="sigmoid")
    ])
    model.compile(optimizer="sgd", loss="binary_crossentropy", metrics=["binary_accuracy"])
    return model

model = build_model()

data_train = predictors[:1200]
labels_train = labels[:1200]
data_test = predictors[1200:]
labels_test = labels[1200:]

k = 4
num_validation_samples = len(data_train) // k
num_epochs = 30
batch_sizes = 32
all_loss_histories = []
all_val_loss_histories = []
all_acc_histories = []
all_val_acc_histories = []

# For each validation fold, we will train a full set of epochs, and store the history.
for fold in range(k):
    validation_data = data_train[num_validation_samples * fold:
                           num_validation_samples * (fold + 1)]
    validation_targets = labels_train[num_validation_samples * fold:
                           num_validation_samples * (fold + 1)]
    training_data = np.concatenate([
        data_train[:num_validation_samples * fold],
        data_train[num_validation_samples * (fold + 1):]])
    training_targets = np.concatenate([
        labels_train[:num_validation_samples * fold],
        labels_train[num_validation_samples * (fold + 1):]])
    model = build_model()
    history = model.fit(training_data, training_targets,
                        validation_data = (validation_data,validation_targets),
                        epochs=num_epochs, batch_size=batch_sizes)
    val_loss_history = history.history['val_loss']
    val_acc_history = history.history['val_binary_accuracy']
    loss_history = history.history['loss']
    acc_history = history.history['binary_accuracy']
    all_val_loss_histories.append(val_loss_history)
    all_loss_histories.append(loss_history)
    all_val_acc_histories.append(val_acc_history)
    all_acc_histories.append(acc_history)
# Out:
# Epoch 1/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - binary_accuracy: 0.5274 - loss: 15.5616 - val_binary_accuracy: 0.6000 - val_loss: 15.4210
# Epoch 2/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - binary_accuracy: 0.6890 - loss: 15.3570 - val_binary_accuracy: 0.6900 - val_loss: 15.2236
# Epoch 3/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.7866 - loss: 15.1484 - val_binary_accuracy: 0.7567 - val_loss: 15.0220
# Epoch 4/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.8516 - loss: 14.9344 - val_binary_accuracy: 0.7800 - val_loss: 14.8223
# Epoch 5/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.8494 - loss: 14.7331 - val_binary_accuracy: 0.7700 - val_loss: 14.6292
# Epoch 6/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.8814 - loss: 14.5162 - val_binary_accuracy: 0.8000 - val_loss: 14.4357
# Epoch 7/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.8991 - loss: 14.3145 - val_binary_accuracy: 0.7767 - val_loss: 14.2602
# Epoch 8/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.9084 - loss: 14.1100 - val_binary_accuracy: 0.8433 - val_loss: 14.0670
# Epoch 9/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.9267 - loss: 13.9312 - val_binary_accuracy: 0.8267 - val_loss: 13.8944
# Epoch 10/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.9376 - loss: 13.7431 - val_binary_accuracy: 0.8367 - val_loss: 13.7292
# Epoch 11/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - binary_accuracy: 0.9328 - loss: 13.5639 - val_binary_accuracy: 0.8267 - val_loss: 13.5541
# Epoch 12/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - binary_accuracy: 0.9393 - loss: 13.3916 - val_binary_accuracy: 0.8300 - val_loss: 13.3903
# Epoch 13/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.9449 - loss: 13.2333 - val_binary_accuracy: 0.8333 - val_loss: 13.2730
# Epoch 14/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.9321 - loss: 13.0804 - val_binary_accuracy: 0.8367 - val_loss: 13.0751
# Epoch 15/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.9528 - loss: 12.8993 - val_binary_accuracy: 0.8333 - val_loss: 12.9398
# Epoch 16/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.9545 - loss: 12.7394 - val_binary_accuracy: 0.8367 - val_loss: 12.7710
# Epoch 17/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.9637 - loss: 12.5836 - val_binary_accuracy: 0.8267 - val_loss: 12.6383
# Epoch 18/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.
# Epoch 3/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.8071 - loss: 15.1347 - val_binary_accuracy: 0.7600 - val_loss: 15.0171
# Epoch 4/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.8507 - loss: 14.9303 - val_binary_accuracy: 0.8133 - val_loss: 14.8126
# Epoch 5/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.9076 - loss: 14.7087 - val_binary_accuracy: 0.8100 - val_loss: 14.6144
# Epoch 6/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.9026 - loss: 14.5125 - val_binary_accuracy: 0.7700 - val_loss: 14.4433
# Epoch 7/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.9054 - loss: 14.3009 - val_binary_accuracy: 0.8333 - val_loss: 14.2415
# Epoch 8/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.9065 - loss: 14.1215 - val_binary_accuracy: 0.8400 - val_loss: 14.0619
# Epoch 9/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.9417 - loss: 13.9337 - val_binary_accuracy: 0.7800 - val_loss: 13.9194
# Epoch 10/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.9157 - loss: 13.7531 - val_binary_accuracy: 0.8300 - val_loss: 13.7212
# Epoch 11/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.9466 - loss: 13.5684 - val_binary_accuracy: 0.8433 - val_loss: 13.5557
# Epoch 12/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.9546 - loss: 13.3831 - val_binary_accuracy: 0.8400 - val_loss: 13.3908
# Epoch 13/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.9384 - loss: 13.2217 - val_binary_accuracy: 0.8167 - val_loss: 13.2379
# Epoch 14/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.9443 - loss: 13.0648 - val_binary_accuracy: 0.8567 - val_loss: 13.0891
# Epoch 15/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.9517 - loss: 12.9038 - val_binary_accuracy: 0.8467 - val_loss: 12.9268
# Epoch 16/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.9569 - loss: 12.7429 - val_binary_accuracy: 0.8300 - val_loss: 12.7836
# Epoch 17/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - binary_accuracy: 0.9540 - loss: 12.5880 - val_binary_accuracy: 0.8567 - val_loss: 12.6336
# Epoch 18/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.9691 - loss: 12.4273 - val_binary_accuracy: 0.8467 - val_loss: 12.4862
# Epoch 19/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.9745 - loss: 12.2693 - val_binary_accuracy: 0.8567 - val_loss: 12.3466
# Epoch 20/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.9702 - loss: 12.1414 - val_binary_accuracy: 0.8533 - val_loss: 12.2050
# Epoch 21/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.9777 - loss: 11.9826 - val_binary_accuracy: 0.8300 - val_loss: 12.0825
# Epoch 22/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.9725 - loss: 11.8484 - val_binary_accuracy: 0.8600 - val_loss: 11.9341
# Epoch 23/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.9870 - loss: 11.6929 - val_binary_accuracy: 0.8467 - val_loss: 11.7966
# Epoch 24/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.9881 - loss: 11.5637 - val_binary_accuracy: 0.8467 - val_loss: 11.6641
# Epoch 25/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.9904 - loss: 11.4205 - val_binary_accuracy: 0.8700 - val_loss: 11.5577
# Epoch 26/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - binary_accuracy: 0.9819 - loss: 11.2917 - val_binary_accuracy: 0.8667 - val_loss: 11.4148
# Epoch 27/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.9902 - loss: 11.1566 - val_binary_accuracy: 0.8600 - val_loss: 11.2847
# Epoch 28/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.9915 - loss: 11.0235 - val_binary_accuracy: 0.8533 - val_loss: 11.1522
# Epoch 29/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.9914 - loss: 10.8989 - val_binary_accuracy: 0.8500 - val_loss: 11.0290
# Epoch 30/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.9922 - loss: 10.7701 - val_binary_accuracy: 0.8533 - val_loss: 10.9054

# %% [markdown]
# *Q: What does 'x' represent in these iterators?*
#
# *Q: Can anyone explain in simple words what this code is doing?*

# %%
average_loss_history = [np.mean([x[i] for x in all_loss_histories]) for i in range(num_epochs)]
average_val_loss_history = [np.mean([x[i] for x in all_val_loss_histories]) for i in range(num_epochs)]
average_acc_history = [np.mean([x[i] for x in all_acc_histories]) for i in range(num_epochs)]
average_val_acc_history = [np.mean([x[i] for x in all_val_acc_histories]) for i in range(num_epochs)]

# %% [markdown]
# Here we plot the cross-validated performance:

# %%
# Plot validation performance.
plt.plot(average_loss_history,c='r')
plt.plot(average_val_loss_history,c='b')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(['Training Loss','Validation Loss'])
plt.show()

plt.plot(average_acc_history,c="r",linestyle="dashed")
plt.plot(average_val_acc_history,c='b',linestyle="dashed")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(['Training Accuracy','Validation Accuracy'])
